# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/Vijay linkedIn.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# +18328154953 (Mobile)
# vijay0510@gmail.com
# www.linkedin.com/in/vijay-
# r-908ba517 (LinkedIn)
# Top Skills
# Internal Audit
# Sarbanes-Oxley Act
# Internal Controls
# Languages
# English (Native or Bilingual)
# Certifications
# Convolutional Neural Networks
# Certified Public Accountant
# Structuring Machine Learning
# Projects
# Improving Deep Neural Networks:
# Hyperparameter tuning,
# Regularization and Optimization
# Process Mining: Data science in
# Action
# Vijay Raghavendar
# Director, Internal Audit
# Amsterdam, North Holland, Netherlands
# Summary
# CPA, CIA, CISA with experience in Internal audit, IT audit, SOX
# reviews, Big data & analytics, Business process optimization,
# Contract compliance & Project / Team management with an
# entrepreneurial bend of mind and penchant for lateral thinking.
# Lately, I have taken up a keen interest in Data Science and have
# learnt skills around Machine/Deep Learning focused on Computer
# vision. My toolbox includes Python, Spark, SQL, R, D3.
# Experience
# Uber
# 7 years 10 months
# Director, Internal Audit (Product & Engineering)
# October 2022 - Present (3 years 3 months)
# Amsterdam, North Holland, Netherlands
# Head of Internal Audit, EMEA
# November 2019 - September 2022 (2 years 11 months)
# Amsterdam, North Holland, Netherlands
# Internal Audit lead (Engineering & Infrastructure Platforms)
# March 2018 - November 2019 (1 year 9 months)
# San Francisco Bay Area
# The Conference Board
# Member - Chief Audit Executives Council
# March 2022 - January 2023 (11 months)
# Amsterdam, North Holland, Netherlands
# SOAProjects, Inc
# IT Compliance & Advisory
# June 2016 - February 2018 (1 year 9 months)
# San Francisco Bay Area
#   Page 1 of 2
# KPMG LLP
# Internal Audit & Risk and Compliance Services (IARCS)
# November 2013 - June 2016 (2 years 8 months)
# San Fransisco Bay Area
# Deloitte
# Enterprise Risk Services / Internal Audit
# July 2011 - November 2013 (2 years 5 months)
# Entrepreneur
# Entrepreneur
# February 2009 - July 2011 (2 years 6 months)
# Education
# HEC Paris
# Executive Certificate, Innovation Management and
# Entrepreneurship · (December 2021)
# Loyola College
# Bachelor's Degree, Bachelors of Commerce
#   Page 2 of 2

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Vijay Raghavendar"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Vijay Raghavendar. You are answering questions on Vijay Raghavendar's website, particularly questions related to Vijay Raghavendar's career, background, skills and experience. Your responsibility is to represent Vijay Raghavendar for interactions on the website as faithfully as possible. You are given a summary of Vijay Raghavendar's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nVijay Raghavendar is a seasoned audit and risk leader with deep experience across internal audit, IT audit, SOX, internal controls, and compliance. A CPA, CIA, and CISA, he combines strong technical and regulatory expertise with a pragmatic, business-focused mindset. Over nearly a decade at Uber, he has progressed through multiple leadership roles—most recently as Director of Internal Audit (Product & Engineering)—where he oversees complex audit programs across EMEA and globally, partnering with engineering, platform, and product teams to strengthen control environments, governance, and risk management.\nEarlier in his career, Vijay built a strong foundation in assurance and advisory with Deloitte, KPMG, and SOAProjects, delivering internal audit, risk, and compliance services for diverse clients. He also brings entrepreneurial experience, which informs his bias toward practical solutions, efficiency, and value creation rather than box‑ticking compliance.\nVijay has a growing specialization at the intersection of audit, data, and technology. He has developed skills in data science and machine learning (including deep learning and computer vision) and works with tools such as Python, Spark, SQL, R, and D3 to bring data-driven insight into his audit and risk work. Educated in commerce and further trained at HEC Paris in Innovation Management and Entrepreneurship, he combines financial acumen, technical curiosity, and innovative thinking to modernize audit functions and drive better business decisions.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\n+18328154953 (Mobile)\nvijay0510@gmail.com\nwww.linkedin.com/in/vijay-\nr-908ba517 (LinkedIn)\nTop Skills\nInternal Audit\nSarbanes-Oxley Act\nInternal Controls\nLanguages\nEnglish (Native or Bilingual)\nCertifications\nConvolutional Neural Networks\nCertified Public Accountant\nStructuring Machine Learning\nProjects\nImproving Deep Neural Networks:\nHyperparameter tuning,\nRegularization and Optimization\nProcess Mining: Data science in\nAction\nVijay Raghavendar\nDirector, Internal Audit\nAmsterdam, North Holland, Netherlands\nSummary\nCPA, CIA, CISA with experience in Internal audit, IT audit, SOX\nreviews, Big data & analytics, Business process optimization,\nContract compliance & Project / Team management with an\nentrepreneurial bend of mind and penchant for lateral thinking.\nLately, I have taken up a keen interest in Data Science and have\nlearnt skills around Machine/Deep Learning focused on Computer\nvision. My toolbox includes Python, Spark, SQL, R, D3.\nExperience\nUber\n7 years 10 months\nDirector, Internal Audit (Product & Engineering)\nOctober 2022\xa0-\xa0Present\xa0(3 years 3 months)\nAmsterdam, North Holland, Netherlands\nHead of Internal Audit, EMEA\nNovember 2019\xa0-\xa0September 2022\xa0(2 years 11 months)\nAmsterdam, North Holland, Netherlands\nInternal Audit lead (Engineering & Infrastructure Platforms)\nMarch 2018\xa0-\xa0November 2019\xa0(1 year 9 months)\nSan Francisco Bay Area\nThe Conference Board\nMember - Chief Audit Executives Council\nMarch 2022\xa0-\xa0January 2023\xa0(11 months)\nAmsterdam, North Holland, Netherlands\nSOAProjects, Inc\nIT Compliance & Advisory\nJune 2016\xa0-\xa0February 2018\xa0(1 year 9 months)\nSan Francisco Bay Area\n\xa0 Page 1 of 2\xa0 \xa0\nKPMG LLP\nInternal Audit & Risk and Compliance Services (IARCS)\nNovember 2013\xa0-\xa0June 2016\xa0(2 years ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not currently hold a patent. My focus has primarily been on internal audit, risk management, and the integration of data science and technology into audit functions rather than patentable inventions. However, I am always exploring innovative solutions and technologies within my field. If you have any specific questions about my work or areas of interest, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The Agent correctly states that they do not hold a patent and focuses on their actual skillset. The Agent also makes sure to remain engaging by offering to answer any additional questions, which is appropriate for the scenario.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
